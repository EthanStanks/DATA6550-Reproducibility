# %% [markdown]
# ## Libraries

# %% [markdown]
# ## Load Data

# %%
# !pip install yfinance
# !pip install scikit-learn
# !pip install tensorflow
# !pip install vaderSentiment
import yfinance as yf
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
# Out:
# Requirement already satisfied: yfinance in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (1.2.0)
# Requirement already satisfied: pandas>=1.3.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (3.0.1)
# Requirement already satisfied: numpy>=1.16.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (2.32.5)
# Requirement already satisfied: multitasking>=0.0.7 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (4.9.4)
# Requirement already satisfied: pytz>=2022.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (2026.1.post1)
# Requirement already satisfied: frozendict>=2.3.4 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (4.0.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (4.14.3)
# Requirement already satisfied: curl_cffi<0.14,>=0.7 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (7.34.1)
# Requirement already satisfied: websockets>=13.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from yfinance) (16.0)
# Requirement already satisfied: cffi>=1.12.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from curl_cffi<0.14,>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: pycparser in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from cffi>=1.12.0->curl_cffi<0.14,>=0.7->yfinance) (2.23)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: scikit-learn in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from scikit-learn) (2.4.4)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: tensorflow in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (7.34.1)
# Requirement already satisfied: requests<3,>=2.21.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (2.32.5)
# Requirement already satisfied: setuptools in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (80.10.2)
# Requirement already satisfied: six>=1.12.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (1.78.0)
# Requirement already satisfied: keras>=3.12.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (2.4.4)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.1.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.46.3)
# Requirement already satisfied: rich in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from keras>=3.12.0->tensorflow) (14.3.3)
# Requirement already satisfied: namex in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from keras>=3.12.0->tensorflow) (0.19.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)
# Requirement already satisfied: vaderSentiment in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (3.3.2)
# Requirement already satisfied: requests in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from vaderSentiment) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests->vaderSentiment) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests->vaderSentiment) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests->vaderSentiment) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in C:\Users\Donovan\anaconda3\envs\Python2025\Lib\site-packages (from requests->vaderSentiment) (2026.1.4)

# %%
# Step 1: Fetch historical stock price data using Yahoo Finance
ticker = "AAPL"  # Apple Inc.
data = yf.download(ticker, start="2024-04-01", end="2025-04-01")
closing_prices = data['Close'].values.reshape(-1, 1)

# Step 2: Analyze sentiment scores from financial news (placeholder text used here)
analyzer = SentimentIntensityAnalyzer()
news_data = ["Sample news article text"]  # Replace with real-time news from a financial API
sentiments = [analyzer.polarity_scores(text)['compound'] for text in news_data]
sentiments = np.array(sentiments).reshape(-1, 1)

# Step 3: Normalize the closing prices and sentiment scores to scale between 0 and 1
scaler = MinMaxScaler()
scaled_prices = scaler.fit_transform(closing_prices)
scaled_sentiments = scaler.fit_transform(sentiments)

# Step 4: Prepare feature sequences using a sliding window approach
# Each input consists of 60 consecutive days of stock prices and sentiment scores
window_size = 60
X, y = [], []

for i in range(window_size, len(scaled_prices)):
    X.append(np.column_stack((
        scaled_prices[i-window_size:i, 0],
        scaled_sentiments[i-window_size:i, 0]
    )))
    y.append(scaled_prices[i, 0])

X, y = np.array(X), np.array(y)

# Step 5: Split the data into training and testing sets (80-20 ratio)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# Step 6: Define the LSTM model architecture
model = Sequential()
model.add(LSTM(64, return_sequences=True, input_shape=(window_size, 2)))  # Two features: price and sentiment
model.add(Dropout(0.2))  # Regularization to prevent overfitting
model.add(LSTM(32))  # Second LSTM layer
model.add(Dense(1))  # Output layer with a single neuron for regression

model.compile(optimizer='adam', loss='mse')

# Step 7: Train the model on the training dataset
model.fit(X_train, y_train, epochs=100, batch_size=32, verbose=1)

# Step 8: Make predictions on the test dataset
predictions = model.predict(X_test)

# Step 9: Inverse transform the predictions and true labels to get actual price values
predictions = scaler.inverse_transform(predictions)
y_test = scaler.inverse_transform([y_test])

# Step 10: Evaluate model performance using MAE and MAPE metrics
mae = np.mean(np.abs(predictions - y_test))
mape = np.mean(np.abs((y_test - predictions) / y_test)) * 100

print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 23
#      20 X, y = [], []
#      22 for i in range(window_size, len(scaled_prices)):
# ---> 23     X.append(np.column_stack((
#      24         scaled_prices[i-window_size:i, 0],
#      25         scaled_sentiments[i-window_size:i, 0]
#      26     )))
#      27     y.append(scaled_prices[i, 0])
#      29 X, y = np.array(X), np.array(y)
#
# File ~\anaconda3\envs\Python2025\Lib\site-packages\numpy\lib\_shape_base_impl.py:666, in column_stack(tup)
#     664         arr = array(arr, copy=None, subok=True, ndmin=2).T
#     665     arrays.append(arr)
# --> 666 return _nx.concatenate(arrays, 1)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 60 and the array at index 1 has size 1
